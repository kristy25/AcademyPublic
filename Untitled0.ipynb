# %% [markdown]
# <a href="https://colab.research.google.com/github/kristy25/AcademyPublic/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# helloworld

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
#create a kaggle folder
# !mkdir ~/.kaggle
# Go on kaggle > Account > Create New API token
# Save the json file in your laptop in a dedicated folder
# copy the kaggle.json to folder created
# !cp kaggle.json ~/.kaggle
#permission for the json to act
# !chmod 600 ~/.kaggle/kaggle.json
# Datasets available here: 
# https://www.kaggle.com/avikpaul4u/vehicle-loan-default-prediction
# !kaggle datasets download -d avikpaul4u/vehicle-loan-default-prediction
# !unzip vehicle-loan-default-prediction.zip
# https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# !kaggle datasets download -d uciml/red-wine-quality-cortez-et-al-2009
# !unzip red-wine-quality-cortez-et-al-2009.zip
# Out:
#      <input type="file" id="files-c7c2bb69-8cca-4f51-9446-bc0d2717cddd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7c2bb69-8cca-4f51-9446-bc0d2717cddd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading vehicle-loan-default-prediction.zip to /content
#  43% 5.00M/11.6M [00:00<00:00, 37.8MB/s]
# 100% 11.6M/11.6M [00:00<00:00, 77.1MB/s]
# Archive:  vehicle-loan-default-prediction.zip
#   inflating: Data Dictionary.xlsx
#   inflating: test.csv
#   inflating: train.csv
# Downloading red-wine-quality-cortez-et-al-2009.zip to /content
#   0% 0.00/25.6k [00:00<?, ?B/s]
# 100% 25.6k/25.6k [00:00<00:00, 22.9MB/s]
# Archive:  red-wine-quality-cortez-et-al-2009.zip
#   inflating: winequality-red.csv

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.dates as mdates
import seaborn as sns

# %%
import pandas as pd # Here I import a library named pandas which is specialized in
# data manipulation. I give an alias pd it is a kind of pseudonyme where pd refers to pandas.
import numpy as np
df = pd.read_csv('/content/winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
21//2
21**2
21%2
# Out:
# 1

# %%
21**2
# Out:
# 441

# %%
a=3
b=5

# %%
a==4
# Out:
# False

# %%
a<2
# Out:
# False

# %%
cities = ['shanghai','rome','london']
cities
# Out:
# ['shanghai', 'rome', 'london']

# %%
type(cities)
# Out:
# list

# %%
cities[0]
# Out:
# 'shanghai'

# %%
print(cities[0])
# Out:
# shanghai

# %%
cities[-1]
# Out:
# 'london'

# %%
cities[-2]
# Out:
# 'rome'

# %%
cities[1]='milan'

# %%
cities[1]
# Out:
# 'milan'

# %%
cities
# Out:
# ['shanghai', 'milan', 'london']

# %%
cities.insert(1,'paris')
cities
# Out:
# ['shanghai', 'paris', 'milan', 'london']

# %%
cities.append('munich')

# %%
cities
# Out:
# ['shanghai', 'paris', 'milan', 'london', 'munich']

# %%
cities.remove('paris')
cities
# Out:
# ['shanghai', 'milan', 'london', 'munich']

# %%
cities.insert(-1,'paris')
print(cities)
cities.remove('munich')
print(cities)
# Out:
# ['shanghai', 'milan', 'london', 'paris', 'munich']
# ['shanghai', 'milan', 'london', 'paris']

# %%
cities.insert(-1,'new')

# %%
cities
# Out:
# ['shanghai', 'milan', 'london', 'new', 'paris']

# %%
cities.insert(0,'new')
cities
# Out:
# ['new', 'shanghai', 'milan', 'london', 'new', 'paris']

# %%
cities.index('shanghai')
# Out:
# 1

# %%
cities.insert(len(cities),'again')

# %%
cities
# Out:
# ['new', 'shanghai', 'milan', 'london', 'new', 'paris', 'again']

# %%
cities.insert(1,286)

# %%
cities
# Out:
# ['new', 286, 'shanghai', 'milan', 'london', 'new', 'paris', 'again']

# %%
var = 0
if var>0:
  print("positive")
elif var==0:
  print('zero')
else:
  print('negative')
# Out:
# zero

# %%
a='me'
b='me'
a is b
# Out:
# True

# %%
list = [1,2,3,4,5,6,7]

# %%
fruits = ['apple','orange','banana']
for i in fruits:
  print(i)
# Out:
# apple
# orange
# banana

# %%
list_of_list = [['a','b','c'],[1,2,3,4]]
list_of_list
# Out:
# [['a', 'b', 'c'], [1, 2, 3, 4]]

# %%
for i in list_of_list:
  print("print list", i)

  for j in i:
    print("print sub list",j)
# Out:
# print list ['a', 'b', 'c']
# print sub list a
# print sub list b
# print sub list c
# print list [1, 2, 3, 4]
# print sub list 1
# print sub list 2
# print sub list 3
# print sub list 4

# %%
def area(len,width):
  if len * width <= 0:
    return print("wrong")
  else:
    return len * width

# %%
area(-10,20)
# Out:
# wrong

# %%
area(11,22)
# Out:
# 242

# %%
# remove multiple numbers with the same value
list=[1,5,6,2,50,2,4,50,5,4,9,50]

toRemove=50

new_list=[value for value in list if value!=toRemove]
new_list
# Out:
# [1, 5, 6, 2, 2, 4, 5, 4, 9]

# %%
list=[1,5,6,2,50,2,4,50,5,4,9,50]

toRemove=50

new_list=[i for i in list if i!=toRemove]
new_list
# Out:
# [1, 5, 6, 2, 2, 4, 5, 4, 9]

# %%
print ("oggi e venerdi")
# Out:
# oggi e venerdi

# %%
# pandas is a library which is specialized in data manipulation
import pandas as pd
import numpy as np

# %%
# function read_csv from the pandas package and assign it to a database (also called dataframe) named df)
df = pd.read_csv('/content/winequality-red.csv')

# %%
# below the dataframe is converted to an interactive table
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
# take 3 samples, but the samples would refresh each time the code is run
df.sample(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 845             6.4             0.640         0.21             1.8      0.081
# 273             8.4             0.715         0.20             2.4      0.076
# 1112            7.9             0.330         0.41             1.5      0.056
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 845                  14.0                  31.0  0.99689  3.59       0.66
# 273                  10.0                  38.0  0.99735  3.31       0.64
# 1112                  6.0                  35.0  0.99396  3.29       0.71
#
#       alcohol  quality
# 845       9.8        5
# 273       9.4        5
# 1112     11.0        6

# %%
# give a specific name to random_state, so that it always shows the same random rows
df.sample(3,random_state=150)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 559           13.0             0.470         0.49             4.3      0.085
# 843            7.1             0.685         0.35             2.0      0.088
# 219            7.8             0.530         0.33             2.4      0.080
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 559                  6.0                  47.0  1.00210  3.30       0.68
# 843                  9.0                  92.0  0.99630  3.28       0.62
# 219                 24.0                 144.0  0.99655  3.30       0.60
#
#      alcohol  quality
# 559     12.7        6
# 843      9.4        5
# 219      9.5        5

# %%
df.sample(3,random_state=100)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1254            7.8              0.70         0.06             1.9      0.079
# 1087            7.9              0.19         0.42             1.6      0.057
# 822             6.7              0.54         0.13             2.0      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1254                 20.0                  35.0  0.99628  3.40       0.69
# 1087                 18.0                  30.0  0.99400  3.29       0.69
# 822                  15.0                  36.0  0.99730  3.61       0.64
#
#       alcohol  quality
# 1254     10.9        5
# 1087     11.2        6
# 822       9.8        5

# %%
# can be used to check whether the data types are changed during data manipulation
# float is with decimals
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# useful to check the data, if the min is below a certain range
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# .info is similar to .dtypes, but including information on missing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.shape
# Out:
# (1599, 12)

# %%
# number of lines
len(df)
# Out:
# 1599

# %%
df['fixed acidity'].head()
# Out:
# 0     7.4
# 1     7.8
# 2     7.8
# 3    11.2
# 4     7.4
# Name: fixed acidity, dtype: float64

# %%
# doesn't work for variable name with space
df.fixed acidity.head()
# Out:
#   File "<ipython-input-30-99764544aa8f>", line 1
#     df.fixed acidity.head()
#                    ^
# SyntaxError: invalid syntax

# %%
df.density.head()
# Out:
# 0    0.9978
# 1    0.9968
# 2    0.9970
# 3    0.9980
# 4    0.9978
# Name: density, dtype: float64

# %%
df.iloc[0]
# Out:
# fixed acidity            7.4000
# volatile acidity         0.7000
# citric acid              0.0000
# residual sugar           1.9000
# chlorides                0.0760
# free sulfur dioxide     11.0000
# total sulfur dioxide    34.0000
# density                  0.9978
# pH                       3.5100
# sulphates                0.5600
# alcohol                  9.4000
# quality                  5.0000
# Name: 0, dtype: float64

# %%
df.loc[0]
# Out:
# fixed acidity            7.4000
# volatile acidity         0.7000
# citric acid              0.0000
# residual sugar           1.9000
# chlorides                0.0760
# free sulfur dioxide     11.0000
# total sulfur dioxide    34.0000
# density                  0.9978
# pH                       3.5100
# sulphates                0.5600
# alcohol                  9.4000
# quality                  5.0000
# Name: 0, dtype: float64

# %%
df.loc[:,'fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
# for more than 1 variable, need double []
df[['fixed acidity','density']].head()
# Out:
#    fixed acidity  density
# 0            7.4   0.9978
# 1            7.8   0.9968
# 2            7.8   0.9970
# 3           11.2   0.9980
# 4            7.4   0.9978

# %%
df.loc[:,'fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
df['fixed acidity']>7
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: fixed acidity, Length: 1599, dtype: bool

# %%
# to embed a condition (df['fixed acidity') inside df to get the sub dataframe
df[df['fixed acidity']>7]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1588                 34.0                 102.0  0.99414  3.27       0.78
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1576     10.8        6
# 1580     11.9        6
# 1585     11.5        6
# 1586     11.4        6
# 1588     12.8        6
#
# [1237 rows x 12 columns]

# %%
mask1=df['fixed acidity']>7
mask1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: fixed acidity, Length: 1599, dtype: bool

# %%
df[mask1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1588                 34.0                 102.0  0.99414  3.27       0.78
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1576     10.8        6
# 1580     11.9        6
# 1585     11.5        6
# 1586     11.4        6
# 1588     12.8        6
#
# [1237 rows x 12 columns]

# %%
# between (left, right, inclusive='both'), by default it's both
temp=df[df['fixed acidity'].between (7,8)]

# %%
df[df['fixed acidity'].between (7,10,'left')]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 4               7.4              0.70         0.00             1.9      0.076
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1588                 34.0                 102.0  0.99414  3.27       0.78
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 4         9.4        5
# 5         9.4        5
# ...       ...      ...
# 1576     10.8        6
# 1580     11.9        6
# 1585     11.5        6
# 1586     11.4        6
# 1588     12.8        6
#
# [1011 rows x 12 columns]

# %%
df[df['fixed acidity'].between (7,10,'right')]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 4               7.4              0.70         0.00             1.9      0.076
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1576            8.0              0.30         0.63             1.6      0.081
# 1580            7.4              0.35         0.33             2.4      0.068
# 1585            7.2              0.39         0.44             2.6      0.066
# 1586            7.5              0.31         0.41             2.4      0.065
# 1588            7.2              0.66         0.33             2.5      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1588                 34.0                 102.0  0.99414  3.27       0.78
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 4         9.4        5
# 5         9.4        5
# ...       ...      ...
# 1576     10.8        6
# 1580     11.9        6
# 1585     11.5        6
# 1586     11.4        6
# 1588     12.8        6
#
# [984 rows x 12 columns]

# %%
df[df['fixed acidity'].between (7,10,'right')].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     984.000000        984.000000   984.000000      984.000000
# mean        8.216260          0.535193     0.260783        2.467226
# std         0.833187          0.182603     0.169777        1.201407
# min         7.100000          0.120000     0.000000        0.900000
# 25%         7.500000          0.400000     0.120000        1.900000
# 50%         8.000000          0.530000     0.260000        2.200000
# 75%         8.900000          0.645000     0.390000        2.600000
# max        10.000000          1.580000     1.000000       13.800000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  984.000000           984.000000            984.000000  984.000000
# mean     0.090821            16.306911             50.574187    0.996767
# std      0.054574            10.216816             35.483646    0.001471
# min      0.038000             1.000000              6.000000    0.990070
# 25%      0.073000             8.000000             23.000000    0.995915
# 50%      0.080000            14.000000             42.000000    0.996800
# 75%      0.091000            23.000000             68.250000    0.997603
# max      0.611000            53.000000            289.000000    1.002420
#
#                pH   sulphates     alcohol     quality
# count  984.000000  984.000000  984.000000  984.000000
# mean     3.298059    0.652744   10.249526    5.582317
# std      0.120047    0.184898    0.991030    0.789898
# min      2.740000    0.330000    8.500000    3.000000
# 25%      3.220000    0.540000    9.500000    5.000000
# 50%      3.300000    0.610000    9.900000    5.000000
# 75%      3.372500    0.720000   10.900000    6.000000
# max      3.670000    2.000000   14.000000    8.000000

# %%
temp[['pH','quality']].sample(n=100,random_state=150)
# Out:
#         pH  quality
# 42    3.21        6
# 1472  3.38        6
# 334   3.34        7
# 1081  3.01        7
# 1398  3.52        7
# ...    ...      ...
# 1313  3.40        6
# 1299  3.50        3
# 1560  3.21        5
# 808   3.26        5
# 1580  3.36        6
#
# [100 rows x 2 columns]

# %%
temp[['pH','quality']].sample(n=100,random_state=150).nunique()
# Out:
# pH         37
# quality     5
# dtype: int64

# %%
# | mean or
mask3 = ((df['residual sugar']<=1.9) | (df['residual sugar'] >=2.3)) & df['sulphates'] <0.7301
mask3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594     True
# 1595     True
# 1596    False
# 1597     True
# 1598    False
# Length: 1599, dtype: bool

# %%
temp=df[mask3]
temp
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 8               7.8             0.580         0.02             2.0      0.073
# 29              7.8             0.645         0.00             2.0      0.082
# 37              8.1             0.380         0.28             2.1      0.066
# 43              8.1             0.660         0.22             2.2      0.069
# 45              4.6             0.520         0.15             2.1      0.054
# ...             ...               ...          ...             ...        ...
# 1575            7.5             0.520         0.40             2.2      0.060
# 1583            6.2             0.460         0.29             2.1      0.074
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 29                    8.0                  16.0  0.99640  3.38       0.59
# 37                   13.0                  30.0  0.99680  3.23       0.73
# 43                    9.0                  23.0  0.99680  3.30       1.20
# 45                    8.0                  65.0  0.99340  3.90       0.56
# ...                   ...                   ...      ...   ...        ...
# 1575                 12.0                  20.0  0.99474  3.26       0.64
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 8         9.5        7
# 29        9.8        6
# 37        9.7        7
# 43       10.3        5
# 45       13.1        4
# ...       ...      ...
# 1575     11.8        6
# 1583      9.8        5
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
#
# [420 rows x 12 columns]

# %%
temp.max()
# Out:
# fixed acidity            15.0000
# volatile acidity          1.5800
# citric acid               0.7200
# residual sugar            2.2500
# chlorides                 0.4220
# free sulfur dioxide      51.0000
# total sulfur dioxide    153.0000
# density                   1.0008
# pH                        3.9000
# sulphates                 1.9800
# alcohol                  14.0000
# quality                   8.0000
# dtype: float64

# %%
def acid_cat(x):
  if x<0.21:
    return 'A'
  elif x<0.3:
    return 'B'
  else:
    return 'C'

# %%
df['citric acid'].max()
# Out:
# 1.0

# %%
acid_cat(df['citric acid'].max())
# Out:
# 'C'

# %%
df['new citric cat']=df['citric acid'].apply(lambda x: acid_cat(x))
df[['new citric cat','citric acid']].sample(10)
# Out:
#      new citric cat  citric acid
# 786               C         0.41
# 472               C         0.55
# 663               C         0.46
# 129               A         0.15
# 1270              A         0.01
# 1216              C         0.31
# 542               B         0.24
# 856               C         0.39
# 783               A         0.14
# 1486              B         0.21

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# new citric cat           object
# dtype: object

# %%
df['new citric cat'].dtypes
# Out:
# dtype('O')

# %%
df1=df.drop(columns=['new citric cat','chlorides'])
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0               7.4             0.700         0.00             1.9
# 1               7.8             0.880         0.00             2.6
# 2               7.8             0.760         0.04             2.3
# 3              11.2             0.280         0.56             1.9
# 4               7.4             0.700         0.00             1.9
# ...             ...               ...          ...             ...
# 1594            6.2             0.600         0.08             2.0
# 1595            5.9             0.550         0.10             2.2
# 1596            6.3             0.510         0.13             2.3
# 1597            5.9             0.645         0.12             2.0
# 1598            6.0             0.310         0.47             3.6
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 11 columns]

# %%
df2=df.drop(columns='new citric cat')
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
mask4 = (((df['residual sugar']<=1.9) | (df['residual sugar'] >=2.3)) & (df['sulphates'] <0.7301) & (df['new citric cat']=='B'))
df[mask4]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 26              7.6              0.41         0.24             1.8      0.080
# 34              5.2              0.32         0.25             1.8      0.103
# 48              6.4              0.40         0.23             1.6      0.066
# 72              7.7              0.69         0.22             1.9      0.084
# 87              7.7              0.49         0.26             1.9      0.062
# ...             ...               ...          ...             ...        ...
# 1493            7.7              0.54         0.26             1.9      0.089
# 1496            7.7              0.54         0.26             1.9      0.089
# 1501            7.8              0.82         0.29             4.3      0.083
# 1514            6.9              0.84         0.21             4.1      0.074
# 1515            6.9              0.84         0.21             4.1      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 26                    4.0                  11.0  0.99620  3.28       0.59
# 34                   13.0                  50.0  0.99570  3.38       0.55
# 48                    5.0                  12.0  0.99580  3.34       0.56
# 72                   18.0                  94.0  0.99610  3.31       0.48
# 87                    9.0                  31.0  0.99660  3.39       0.64
# ...                   ...                   ...      ...   ...        ...
# 1493                 23.0                 147.0  0.99636  3.26       0.59
# 1496                 23.0                 147.0  0.99636  3.26       0.59
# 1501                 21.0                  64.0  0.99642  3.16       0.53
# 1514                 16.0                  65.0  0.99842  3.53       0.72
# 1515                 16.0                  65.0  0.99842  3.53       0.72
#
#        alcohol  quality new citric cat
# 26    9.500000        5              B
# 34    9.200000        5              B
# 48    9.200000        5              B
# 72    9.500000        5              B
# 87    9.600000        5              B
# ...        ...      ...            ...
# 1493  9.700000        5              B
# 1496  9.700000        5              B
# 1501  9.400000        5              B
# 1514  9.233333        6              B
# 1515  9.250000        6              B
#
# [143 rows x 13 columns]

# %%
list_to_keep = ['A','B']

# %%
# isin
#value_counts()
mask6=((df['sulphates'] <0.7301) & df['new citric cat'].isin(list_to_keep))
df[mask6]['new citric cat'].value_counts()
# Out:
# A    553
# B    218
# Name: new citric cat, dtype: int64

# %%
# ~ is to take the complementary
mask6=((df['sulphates'] <0.7301) & (~df['new citric cat'].isin(list_to_keep)))
df[mask6]['new citric cat'].value_counts()
# Out:
# C    442
# Name: new citric cat, dtype: int64

# %%
mask6=((df['sulphates'] <0.7301) & (df['new citric cat']!='A'))
df[mask6]['new citric cat'].value_counts()
# Out:
# C    442
# B    218
# Name: new citric cat, dtype: int64

# %%
df['Y1']=np.where(df['quality']>=7,1,0)
df['Y2']=np.where(df['quality']>=7,1,df['quality'])
df=df.drop(columns='Y')
df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 118             8.8             0.550         0.04             2.2      0.119
# 878             8.8             0.610         0.19             4.0      0.094
# 285             9.9             0.590         0.07             3.4      0.102
# 589            10.2             0.290         0.49             2.6      0.059
# 1317            9.9             0.440         0.46             2.2      0.091
# 1527            7.1             0.530         0.07             1.7      0.071
# 1207            9.9             0.720         0.55             1.7      0.136
# 861             5.8             1.010         0.66             2.0      0.039
# 1164            9.0             0.785         0.24             1.7      0.078
# 1231            7.8             0.815         0.01             2.6      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 118                  14.0                  56.0  0.99620  3.21       0.60
# 878                  30.0                  69.0  0.99787  3.22       0.50
# 285                  32.0                  71.0  1.00015  3.31       0.71
# 589                   5.0                  13.0  0.99760  3.05       0.74
# 1317                 10.0                  41.0  0.99638  3.18       0.69
# 1527                 15.0                  24.0  0.99510  3.29       0.66
# 1207                 24.0                  52.0  0.99752  3.35       0.94
# 861                  15.0                  88.0  0.99357  3.66       0.60
# 1164                 10.0                  21.0  0.99692  3.29       0.67
# 1231                 48.0                  90.0  0.99621  3.38       0.62
#
#       alcohol  quality new citric cat  Y1  Y2
# 118      10.9        6              A   0   6
# 878      10.0        6              A   0   6
# 285       9.8        5              A   0   5
# 589      10.5        7              C   1   1
# 1317     11.9        6              C   0   6
# 1527     10.8        6              A   0   6
# 1207     10.0        5              C   0   5
# 861      11.5        6              C   0   6
# 1164     10.0        5              B   0   5
# 1231     10.8        5              A   0   5

# %%
# Now let's complexify the database in order to have additional work to do later! Not important to understand
# Educational purpose
# Here I create a binary feature who will be used as target
# We use the numpy.where function which is equivalent to a if-then-else statement
# If df['quality'] >= 7 then df['Y']=1, else df['Y']=0
df['Y'] = np.where(df['quality']>= 7, 1, 0)
# We create as well some binary features of 'fixed acidity' & 'volatile acidity'
df['fixed_acidity_cat'] = np.where(df['fixed acidity']<= 8, 0, 1)
df['volatile_acidity_cat'] = np.where(df['volatile acidity']>= 0.4, 0, 1)
# Here I create some duplicates rows: I do a random sample of df and then I concat them at the end of df
temp = df.sample(n=150, random_state=893717398)
df = df.append(temp)
del(temp)
df.reset_index(drop=True, inplace=True)
# Here I create a new feature pH2 from pH where I had some missing values
df['pH2'] = np.where(df['pH'].index %15 ==0, np.nan, df['pH'])
# Here I create a n

# %%
# Here I create a new random feature 'acidity_other' from 'fixed acidity' and I create some missing values
rng = np.random.default_rng(893717398)
df = df.join(pd.Series(rng.normal(df['fixed acidity'].median(),1,len(df)), name='acidity_other'))
df['acidity_other'] = np.where(df['acidity_other'].index %2 !=0, np.nan, df['pH'])

#Here it is a function that will automatically create a feature of random dates between a defined interval
def random_datetimes_or_dates(start, end, out_format='datetime', n=10): 

    '''   
    unix timestamp is in ns by default. 
    I divide the unix time value by 10**9 to make it seconds 
    (or 24*60*60*10**9 to make it days).
    The corresponding unit variable is passed to 
    the pd.to_datetime function. 
    Values for the (divide_by, unit) pair to select is defined by 
    the out_format parameter.
    for 1 -> out_format='datetime'
    for 2 -> out_format=anything else
    '''
    (divide_by, unit) = (10**9, 's') if out_format=='datetime' else (24*60*60*10**9, 'D')

    start_u = start.value//divide_by
    end_u = end.value//divide_by

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit=unit)

# Now I apply my function in order to create the new feature 'date'
np.random.seed(893717398)
d_start = pd.to_datetime('2021-01-01')
d_end = pd.to_datetime('2021-06-30')
df['date'] = random_datetimes_or_dates(d_start, d_end, out_format='datetime', n=len(df))
df['date'] = df['date'].astype(str)

## End of the complexification

# %%
# Here I create a function having the name citric_acid_cat with the parameter x
# In the function, x will pass within a conditional statement. Given the value,
# it will return a letter (a category):
def citric_acid_cat(x):
  if x < 0.21 :
    return 'A'
  elif x < 0.3 :
    return 'B'
  else:
    return 'C'
# Now we want to create a new feature citric_cat, which transform the numerical value
# of citric acid to the category defined above for each line of the feature.
# We could create a for loop. However the apply lambda is more efficient from a computing point of view 
# The x refers to the x of the function which is df['citric acid']
df['citric_cat'] = df['citric acid'].apply(lambda x: citric_acid_cat(x))

# %%
df['citric_cat']=np.where(df['citric_cat']=='C', 'Z',df['citric_cat'])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Y  fixed_acidity_cat  volatile_acidity_cat   pH2  \
# 0      9.4        5  0                  0                     0   NaN
# 1      9.8        5  0                  0                     0  3.20
# 2      9.8        5  0                  0                     0  3.26
# 3      9.8        6  0                  1                     1  3.16
# 4      9.4        5  0                  0                     0  3.51
#
#    acidity_other                 date citric_cat
# 0           3.51  2021-01-06 14:38:36          A
# 1            NaN  2021-02-07 08:11:30          A
# 2           3.26  2021-06-27 12:25:26          A
# 3            NaN  2021-06-16 05:25:38          Z
# 4           3.51  2021-01-20 10:10:16          A

# %%
df['citric_cat'].value_counts()
# Out:
# Z    773
# A    693
# B    283
# Name: citric_cat, dtype: int64

# %%
df['citric_cat'].value_counts(True)
# Out:
# Z    0.441967
# A    0.396226
# B    0.161807
# Name: citric_cat, dtype: float64

# %%
np.round(df['citric_cat'].value_counts(True)*100,2)
# Out:
# Z    44.20
# A    39.62
# B    16.18
# Name: citric_cat, dtype: float64

# %%
df.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1744          False             False        False           False      False
# 1745          False             False        False           False      False
# 1746          False             False        False           False      False
# 1747          False             False        False           False      False
# 1748          False             False        False           False      False
#
#       free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                   False                 False    False  False      False
# 1                   False                 False    False  False      False
# 2                   False                 False    False  False      False
# 3                   False                 False    False  False      False
# 4                   False                 False    False  False      False
# ...                   ...                   ...      ...    ...        ...
# 1744                False                 False    False  False      False
# 1745                False                 False    False  False      False
# 1746                False                 False    False  False      False
# 1747                False                 False    False  False      False
# 1748                False                 False    False  False      False
#
#       alcohol  quality      Y  fixed_acidity_cat  volatile_acidity_cat    pH2  \
# 0       False    False  False              False                 False   True
# 1       False    False  False              False                 False  False
# 2       False    False  False              False                 False  False
# 3       False    False  False              False                 False  False
# 4       False    False  False              False                 False  False
# ...       ...      ...    ...                ...                   ...    ...
# 1744    False    False  False              False                 False  False
# 1745    False    False  False              False                 False  False
# 1746    False    False  False              False                 False  False
# 1747    False    False  False              False                 False  False
# 1748    False    False  False              False                 False  False
#
#       acidity_other   date  ph_test  citric_cat
# 0             False  False    False       False
# 1              True  False    False       False
# 2             False  False    False       False
# 3              True  False    False       False
# 4             False  False    False       False
# ...             ...    ...      ...         ...
# 1744          False  False    False       False
# 1745           True  False    False       False
# 1746          False  False    False       False
# 1747           True  False    False       False
# 1748          False  False    False       False
#
# [1749 rows x 20 columns]

# %%
# True returns 1, False returns 0
#by column
df.isna().sum()
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid               0
# residual sugar            0
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                   0
# pH                        0
# sulphates                 0
# alcohol                   0
# quality                   0
# Y                         0
# fixed_acidity_cat         0
# volatile_acidity_cat      0
# pH2                     117
# acidity_other           874
# date                      0
# citric_cat                0
# dtype: int64

# %%
#by row
df.isna().sum(1)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1744    0
# 1745    1
# 1746    0
# 1747    1
# 1748    0
# Length: 1749, dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Y                         int64
# fixed_acidity_cat         int64
# volatile_acidity_cat      int64
# pH2                     float64
# acidity_other           float64
# date                     object
# citric_cat               object
# dtype: object

# %%
df.date.head()
# Out:
# 0    2021-01-06 14:38:36
# 1    2021-02-07 08:11:30
# 2    2021-06-27 12:25:26
# 3    2021-06-16 05:25:38
# 4    2021-01-20 10:10:16
# Name: date, dtype: object

# %%
# Check python doc
# strftime () and strptime() format codes, check the table
df['date']=pd.to_datetime(df['date'],format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# fixed acidity                  float64
# volatile acidity               float64
# citric acid                    float64
# residual sugar                 float64
# chlorides                      float64
# free sulfur dioxide            float64
# total sulfur dioxide           float64
# density                        float64
# pH                             float64
# sulphates                      float64
# alcohol                        float64
# quality                          int64
# Y                                int64
# fixed_acidity_cat                int64
# volatile_acidity_cat             int64
# pH2                            float64
# acidity_other                  float64
# date                    datetime64[ns]
# citric_cat                      object
# dtype: object

# %%
today = pd.to_datetime('2022-04-22', format='%Y-%m-%d')
today
# Out:
# Timestamp('2022-04-22 00:00:00')

# %%
df['time_diff'] = today-df['date']
df['time_diff'].head()
# Out:
# 0   470 days 09:21:24
# 1   438 days 15:48:30
# 2   298 days 11:34:34
# 3   309 days 18:34:22
# 4   456 days 13:49:44
# Name: time_diff, dtype: timedelta64[ns]

# %%
# to transfer the hours to days or months, using np.timedelta64, which is a duration
df['day_diff']=(df['time_diff']/np.timedelta64(1,'M')).astype(float)
df['day_diff']
# Out:
# 0       15.454604
# 1       14.412080
# 2        9.806603
# 3       10.177584
# 4       15.000758
#           ...
# 1744    13.848856
# 1745    10.326506
# 1746    10.589150
# 1747    13.647306
# 1748    13.066725
# Name: day_diff, Length: 1749, dtype: float64

# %%
df['day_diff']=(df['time_diff']/np.timedelta64(1,'Y')).astype(float)
df['day_diff']
# Out:
# 0       1.287884
# 1       1.201007
# 2       0.817217
# 3       0.848132
# 4       1.250063
#           ...
# 1744    1.154071
# 1745    0.860542
# 1746    0.882429
# 1747    1.137275
# 1748    1.088894
# Name: day_diff, Length: 1749, dtype: float64

# %%
df['day_diff']=(df['time_diff']/np.timedelta64(1,'D')).astype(float)
df['day_diff']
# Out:
# 0       470.389861
# 1       438.658681
# 2       298.482338
# 3       309.773866
# 4       456.576204
#            ...
# 1744    421.515891
# 1745    314.306586
# 1746    322.300637
# 1747    415.381343
# 1748    397.710289
# Name: day_diff, Length: 1749, dtype: float64

# %%
# merges
# np.random.normal(a,b,c)
# a is Mean (“centre”) of the distribution, b is Standard deviation of the distribution, c is Output shape
np.random.seed(893717398)
randomf1 = pd.Series(np.random.normal(0, 1, len(df)), name='Random_Normal_feature1')
randomf2 = pd.Series(np.random.normal(1, 0.5, len(df)), name='Random_Normal_feature2')

# %%
randomf1
# Out:
# 0      -1.631267
# 1       1.047653
# 2      -0.226178
# 3      -0.930432
# 4      -0.047275
#           ...
# 1744    1.320290
# 1745    0.311190
# 1746   -2.410861
# 1747   -1.779215
# 1748    0.365288
# Name: Random_Normal_feature1, Length: 1749, dtype: float64

# %%
randomf2
# Out:
# 0       1.407202
# 1       1.086529
# 2       0.852965
# 3       0.634562
# 4       1.816503
#           ...
# 1744    0.899144
# 1745    0.637923
# 1746    0.235571
# 1747    1.310266
# 1748    1.075226
# Name: Random_Normal_feature2, Length: 1749, dtype: float64

# %%
randomf=pd.concat([randomf1,randomf2],axis=1,ignore_index=True)
randomf.columns=['Random_Normal_feature1','Random_Normal_feature2']
randomf
# Out:
#       Random_Normal_feature1  Random_Normal_feature2
# 0                  -1.631267                1.407202
# 1                   1.047653                1.086529
# 2                  -0.226178                0.852965
# 3                  -0.930432                0.634562
# 4                  -0.047275                1.816503
# ...                      ...                     ...
# 1744                1.320290                0.899144
# 1745                0.311190                0.637923
# 1746               -2.410861                0.235571
# 1747               -1.779215                1.310266
# 1748                0.365288                1.075226
#
# [1749 rows x 2 columns]

# %%
randomf=pd.concat([randomf1,randomf2],axis=0,ignore_index=True)
randomf.columns=['Random_Normal_feature1','Random_Normal_feature2']
randomf
# Out:
# 0      -1.631267
# 1       1.047653
# 2      -0.226178
# 3      -0.930432
# 4      -0.047275
#           ...
# 3493    0.899144
# 3494    0.637923
# 3495    0.235571
# 3496    1.310266
# 3497    1.075226
# Length: 3498, dtype: float64

# %%
np.random.seed(893717398)
df['Random_Normal_feature1']=pd.Series(np.random.normal(0,1,len(df)),name='Random_Normal_feature1')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  ...  \
# 0                 11.0                  34.0   0.9978  3.51       0.56  ...
# 1                 25.0                  67.0   0.9968  3.20       0.68  ...
# 2                 15.0                  54.0   0.9970  3.26       0.65  ...
# 3                 17.0                  60.0   0.9980  3.16       0.58  ...
# 4                 11.0                  34.0   0.9978  3.51       0.56  ...
#
#    Y  fixed_acidity_cat  volatile_acidity_cat   pH2  acidity_other  \
# 0  0                  0                     0   NaN           3.51
# 1  0                  0                     0  3.20            NaN
# 2  0                  0                     0  3.26           3.26
# 3  0                  1                     1  3.16            NaN
# 4  0                  0                     0  3.51           3.51
#
#                  date  citric_cat         time_diff    day_diff  \
# 0 2021-01-06 14:38:36           A 470 days 09:21:24  470.389861
# 1 2021-02-07 08:11:30           A 438 days 15:48:30  438.658681
# 2 2021-06-27 12:25:26           A 298 days 11:34:34  298.482338
# 3 2021-06-16 05:25:38           Z 309 days 18:34:22  309.773866
# 4 2021-01-20 10:10:16           A 456 days 13:49:44  456.576204
#
#   Random_Normal_feature1
# 0              -1.631267
# 1               1.047653
# 2              -0.226178
# 3              -0.930432
# 4              -0.047275
#
# [5 rows x 22 columns]

# %%
#merge
# how: left, right, inner, outer
# on: name of the key, variable to link two datasets. If variable names are different, use: left_on=, right_on=
df = df.merge(randomf,how='inner',on='Random_Normal_feature1')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  ...  \
# 0                 11.0                  34.0   0.9978  3.51       0.56  ...
# 1                 25.0                  67.0   0.9968  3.20       0.68  ...
# 2                 15.0                  54.0   0.9970  3.26       0.65  ...
# 3                 17.0                  60.0   0.9980  3.16       0.58  ...
# 4                 11.0                  34.0   0.9978  3.51       0.56  ...
#
#    volatile_acidity_cat   pH2  acidity_other                date  citric_cat  \
# 0                     0   NaN           3.51 2021-01-06 14:38:36           A
# 1                     0  3.20            NaN 2021-02-07 08:11:30           A
# 2                     0  3.26           3.26 2021-06-27 12:25:26           A
# 3                     1  3.16            NaN 2021-06-16 05:25:38           Z
# 4                     0  3.51           3.51 2021-01-20 10:10:16           A
#
#           time_diff    day_diff Random_Normal_feature1  \
# 0 470 days 09:21:24  470.389861              -1.631267
# 1 438 days 15:48:30  438.658681               1.047653
# 2 298 days 11:34:34  298.482338              -0.226178
# 3 309 days 18:34:22  309.773866              -0.930432
# 4 456 days 13:49:44  456.576204              -0.047275
#
#   Random_Normal_feature2_x Random_Normal_feature2_y
# 0                 1.407202                 1.407202
# 1                 1.086529                 1.086529
# 2                 0.852965                 0.852965
# 3                 0.634562                 0.634562
# 4                 1.816503                 1.816503
#
# [5 rows x 24 columns]

# %%
df['quality'].value_counts()
# Out:
# 5    744
# 6    700
# 7    216
# 4     59
# 8     19
# 3     11
# Name: quality, dtype: int64

# %%
df.groupby('citric_cat')['quality'].mean()
# Out:
# citric_cat
# A    5.458874
# B    5.395760
# Z    5.877102
# Name: quality, dtype: float64

# %%
df.groupby(['citric_cat','quality'])[['sulphates','fixed acidity']].mean()
# Out:
#                     sulphates  fixed acidity
# citric_cat quality
# A          3         0.520000       7.314286
#            4         0.558684       7.076316
#            5         0.575152       7.321646
#            6         0.634432       7.208791
#            7         0.705000       6.679545
#            8         0.793333       6.300000
# B          4         0.528750       8.362500
#            5         0.615679       7.991975
#            6         0.680467       7.885047
#            7         0.582000       6.860000
#            8         0.740000       5.000000
# Z          3         0.672500      10.700000
#            4         0.703846       9.569231
#            5         0.675591       9.347244
#            6         0.709063       9.430938
#            7         0.755090       9.550299
#            8         0.774667       9.313333

# %%
pd.pivot_table(df,values='sulphates',index=['Y','quality'],
               columns=['citric_cat'],aggfunc=np.mean)
# Out:
# citric_cat         A         B         Z
# Y quality
# 0 3         0.520000       NaN  0.672500
#   4         0.558684  0.528750  0.703846
#   5         0.575152  0.615679  0.675591
#   6         0.634432  0.680467  0.709063
# 1 7         0.705000  0.582000  0.755090
#   8         0.793333  0.740000  0.774667

# %%
# create a copy of df and remains the version at this moment
# if df1=df, then df1 will always point to the df, even if subsequent changes are made to df
df1=df.copy()

# %%
df_barplot=pd.DataFrame(df.groupby('citric_cat')['quality'].median()).reset_index()
df_barplot
# Out:
#   citric_cat  quality
# 0          A      5.0
# 1          B      5.0
# 2          Z      6.0

# %%
# we need to define a figure and a Axes. Note Axes is different to axis
fig1,ax=plt.subplots() # it always starts like this

# define the kind of visualization you want
ax.bar(x=df_barplot['citric_cat'],height=df_barplot['quality'])
plt.show()
